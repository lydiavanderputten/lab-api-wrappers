# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#create a dataframe that includes name, artist uri, features

# %%
secrets_file = open("secrets.txt","r")

# %%
string = secrets_file.read()

# %%
string.split('\n')
# Out:
# ['cid:a331734a37e44268bbb50db5a966ac03',
#  'csecret:a871cca90fc041b683454162ff7d6de4']

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

# %%
secrets_dict
# Out:
# {'cid': 'a331734a37e44268bbb50db5a966ac03',
#  'csecret': 'a871cca90fc041b683454162ff7d6de4'}

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'],
                                                           client_secret=secrets_dict['csecret']))

# %%
playlist = sp.user_playlist_tracks("spotify", "30TI3KL6mgjAHsE40w27cZ?si=65887620d2754111&nd=1")

# %%
playlist["tracks"]["total"]
# Out:
# 831

# %%
playlist
# Out:
# {'collaborative': False,
#  'description': 'Here&#x27;s the perfect playlist for your working hours. Your coworkers will be hanging out at your desk all day! List is regularly updated.',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/30TI3KL6mgjAHsE40w27cZ'},
#  'followers': {'href': None, 'total': 1537},
#  'href': 'https://api.spotify.com/v1/playlists/30TI3KL6mgjAHsE40w27cZ?additional_types=track',
#  'id': '30TI3KL6mgjAHsE40w27cZ',
#  'images': [{'height': None,
#    'url': 'https://i.scdn.co/image/ab67706c0000bebbc0b9654eeda68397c20f1d02',
#    'width': None}],
#  'name': 'The Perfect Work Playlist (Updated Regularly)',
#  'owner': {'display_name': 'Playlist Giants',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/playlistgiants'},
#   'href': 'https://api.spotify.com/v1/users/playlistgiants',
#   'id': 'playlistgiants',
#   'type': 'user',
#   'uri': 'spotify:user:playlistgiants'},
#  'primary_color': None,
#  'public': True,
# ...

# %%
playlist.keys()
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'followers', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])

# %%
tracks = get_name_artists_from_track

# %%
my_track = results["tracks"]

# %%
playlist["name"]
# Out:
# 'The Perfect Work Playlist (Updated Regularly)'

# %%
playlist["description"]
# Out:
# 'Here&#x27;s the perfect playlist for your working hours. Your coworkers will be hanging out at your desk all day! List is regularly updated.'

# %%
playlist["tracks"]["total"]
# Out:
# 831

# %%
playlist["tracks"].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist['tracks']['items'][0]
# Out:
# {'added_at': '2020-08-05T17:49:35Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/playlistgiants'},
#   'href': 'https://api.spotify.com/v1/users/playlistgiants',
#   'id': 'playlistgiants',
#   'type': 'user',
#   'uri': 'spotify:user:playlistgiants'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5xZglTXVKOkpkC70KMPis9'},
#      'href': 'https://api.spotify.com/v1/artists/5xZglTXVKOkpkC70KMPis9',
#      'id': '5xZglTXVKOkpkC70KMPis9',
#      'name': 'Brother James',
#      'type': 'artist',
#      'uri': 'spotify:artist:5xZglTXVKOkpkC70KMPis9'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
# ...

# %%
playlist["name"]

# %%
len(playlist["tracks"]["items"])
# Out:
# 100

# %%
playlist["tracks"]["items"]
# Out:
# [{'added_at': '2020-08-05T17:49:35Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/playlistgiants'},
#    'href': 'https://api.spotify.com/v1/users/playlistgiants',
#    'id': 'playlistgiants',
#    'type': 'user',
#    'uri': 'spotify:user:playlistgiants'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5xZglTXVKOkpkC70KMPis9'},
#       'href': 'https://api.spotify.com/v1/artists/5xZglTXVKOkpkC70KMPis9',
#       'id': '5xZglTXVKOkpkC70KMPis9',
#       'name': 'Brother James',
#       'type': 'artist',
#       'uri': 'spotify:artist:5xZglTXVKOkpkC70KMPis9'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
# ...

# %%
playlist["tracks"]["items"][0]
# Out:
# {'added_at': '2020-08-05T17:49:35Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/playlistgiants'},
#   'href': 'https://api.spotify.com/v1/users/playlistgiants',
#   'id': 'playlistgiants',
#   'type': 'user',
#   'uri': 'spotify:user:playlistgiants'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5xZglTXVKOkpkC70KMPis9'},
#      'href': 'https://api.spotify.com/v1/artists/5xZglTXVKOkpkC70KMPis9',
#      'id': '5xZglTXVKOkpkC70KMPis9',
#      'name': 'Brother James',
#      'type': 'artist',
#      'uri': 'spotify:artist:5xZglTXVKOkpkC70KMPis9'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
# ...

# %%
for track in playlist:
    print (track)
# Out:
# collaborative
# description
# external_urls
# followers
# href
# id
# images
# name
# owner
# primary_color
# public
# snapshot_id
# tracks
# type
# uri

# %%
#songname

playlist['tracks']['items'][4]['track']['name']
# Out:
# 'Samba of Brazil'

# %%
def song_names(playlist):
    song_names = [playlist['tracks']['items'][i]['track']['name']for i in range(len(playlist))]
    return song_names

# %%
song_names(playlist)
# Out:
# ['Give Yourself a Break',
#  'Up',
#  'Meteors',
#  "Ella's Reel",
#  'Samba of Brazil',
#  'Only Flies',
#  'Back in the Tri-Town',
#  'Come To Me',
#  'Found You',
#  'Rivers',
#  'So Good to Be Free',
#  'Prelude in D Maj, Cello Suite 1: BWV 1007',
#  'Mastapiece',
#  'Losing Hold',
#  'Pastures of Plenty']

# %%
#artist number 1

playlist['tracks']['items'][0]['track']['album']['artists'][0]#['name']


#['items'] #[0]["name"]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/5xZglTXVKOkpkC70KMPis9'},
#  'href': 'https://api.spotify.com/v1/artists/5xZglTXVKOkpkC70KMPis9',
#  'id': '5xZglTXVKOkpkC70KMPis9',
#  'name': 'Brother James',
#  'type': 'artist',
#  'uri': 'spotify:artist:5xZglTXVKOkpkC70KMPis9'}

# %%
def artist_names(playlist):
    artist_names = [playlist['tracks']['items'][i]['track']['album']['artists'][0]['name']for i in range(len(playlist))]
    return artist_names

# %%
artist_names(playlist)
# Out:
# ['Brother James',
#  'telco',
#  'Gavriel',
#  'Sebastian Blue',
#  'Jack Jezzro',
#  'Edan Laniado',
#  'Through the Ruins',
#  'Chantel Van T',
#  'Qwiet Type',
#  'Thomas LaVine',
#  'Angela Predhomme',
#  'Mark Bodino',
#  'ellee ven',
#  'Chris Wenner',
#  'Harp & Plow']

# %%
playlist['tracks']['items'][0]['track']['album']['artists'][0]['name']
# Out:
# 'Brother James'

# %%
#artist number 2

playlist['tracks']['items'][1]['track']['album']['artists'][0]#['name']
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/6M6obxInga7XUzdpC7irmd'},
#  'href': 'https://api.spotify.com/v1/artists/6M6obxInga7XUzdpC7irmd',
#  'id': '6M6obxInga7XUzdpC7irmd',
#  'name': 'telco',
#  'type': 'artist',
#  'uri': 'spotify:artist:6M6obxInga7XUzdpC7irmd'}

# %%
playlist['tracks']['items'][1]['track']['album']['artists'][0]['name']
# Out:
# 'telco'

# %%
playlist = sp.user_playlist_tracks("spotify", "4rnleEAOdmFAbRcNCgZMpY")

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/4rnleEAOdmFAbRcNCgZMpY/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2017-06-09T17:34:13Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FXC3k01G6Gw61bmprjgqS'},
#        'href': 'https://api.spotify.com/v1/artists/2FXC3k01G6Gw61bmprjgqS',
#        'id': '2FXC3k01G6Gw61bmprjgqS',
#        'name': 'Hozier',
#        'type': 'artist',
#        'uri': 'spotify:artist:2FXC3k01G6Gw61bmprjgqS'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7HW03Zew4rnOhy5uwskRSz'},
# ...

# %%
song_uri = playlist["items"][46]["track"]["uri"]

# %%
sp.audio_features(song_uri)
# Out:
# [{'danceability': 0.688,
#   'energy': 0.532,
#   'key': 6,
#   'loudness': -8.361,
#   'mode': 0,
#   'speechiness': 0.0875,
#   'acousticness': 0.0356,
#   'instrumentalness': 3.08e-06,
#   'liveness': 0.172,
#   'valence': 0.565,
#   'tempo': 164.068,
#   'type': 'audio_features',
#   'id': '3KZcrZ36LW9RnChK1iIkth',
#   'uri': 'spotify:track:3KZcrZ36LW9RnChK1iIkth',
#   'track_href': 'https://api.spotify.com/v1/tracks/3KZcrZ36LW9RnChK1iIkth',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3KZcrZ36LW9RnChK1iIkth',
#   'duration_ms': 223079,
#   'time_signature': 4}]

# %%
features_song = sp.audio_features(song_uri)

# %%
features_song
# Out:
# [{'danceability': 0.688,
#   'energy': 0.532,
#   'key': 6,
#   'loudness': -8.361,
#   'mode': 0,
#   'speechiness': 0.0875,
#   'acousticness': 0.0356,
#   'instrumentalness': 3.08e-06,
#   'liveness': 0.172,
#   'valence': 0.565,
#   'tempo': 164.068,
#   'type': 'audio_features',
#   'id': '3KZcrZ36LW9RnChK1iIkth',
#   'uri': 'spotify:track:3KZcrZ36LW9RnChK1iIkth',
#   'track_href': 'https://api.spotify.com/v1/tracks/3KZcrZ36LW9RnChK1iIkth',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3KZcrZ36LW9RnChK1iIkth',
#   'duration_ms': 223079,
#   'time_signature': 4}]

# %%
import pandas as pd

# %%
features = pd.DataFrame(features_song)

# %%
features
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.688   0.532    6    -8.361     0       0.0875        0.0356
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000003     0.172    0.565  164.068  audio_features
#
#                        id                                   uri  \
# 0  3KZcrZ36LW9RnChK1iIkth  spotify:track:3KZcrZ36LW9RnChK1iIkth
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3KZcrZ36LW9R...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3KZc...       223079
#
#    time_signature
# 0               4

# %%
danceability = [song_features_df['features'][i]['danceability'] for i in range(len(song_features_df))]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-360-f640080f8e00> in <module>
# ----> 1 danceability = [song_features_df['features'][i]['danceability'] for i in range(len(song_features_df))]
#
# NameError: name 'song_features_df' is not defined
